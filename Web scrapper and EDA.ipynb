# %%
pip install --upgrade pip
# Out:
# ...
#                                               0.0/2.1 MB ? eta -:--:--
#      -----                                    0.3/2.1 MB 8.9 MB/s eta 0:00:01
#      ----------                               0.6/2.1 MB 5.9 MB/s eta 0:00:01
#      -----------                              0.6/2.1 MB 4.1 MB/s eta 0:00:01
#      ------------------                       1.0/2.1 MB 5.6 MB/s eta 0:00:01
#      ----------------------                   1.2/2.1 MB 5.3 MB/s eta 0:00:01
#      --------------------------               1.4/2.1 MB 5.2 MB/s eta 0:00:01
#      ------------------------------           1.6/2.1 MB 5.1 MB/s eta 0:00:01
#      -----------------------------------      1.9/2.1 MB 5.2 MB/s eta 0:00:01
#      ------------------------------------     1.9/2.1 MB 5.2 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 4.9 MB/s eta 0:00:01
#      ---------------------------------------  2.1/2.1 MB 4.9 MB/s eta 0:00:01
# ...

# %%
pip install lxml
# Out:
# ...
#
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/31/58/e3b3dd6bb2ab7404f1f4992e2d0e6926ed40cef8ce1b3bbefd95877499e1/lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    -- ------------------------------------- 0.2/3.8 MB 6.3 MB/s eta 0:00:01
#    ----- ---------------------------------- 0.5/3.8 MB 6.6 MB/s eta 0:00:01
#    ---------- ----------------------------- 1.0/3.8 MB 8.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.8 MB 9.1 MB/s eta 0:00:01
#    ---------------------- ----------------- 2.2/3.8 MB 9.8 MB/s eta 0:00:01
#    --------------------------- ------------ 2.6/3.8 MB 9.8 MB/s eta 0:00:01
#    -------------------------------- ------- 3.1/3.8 MB 10.4 MB/s eta 0:00:01
#    -------------------------------------- - 3.6/3.8 MB 10.5 MB/s eta 0:00:01
#    ---------------------------------------  3.8/3.8 MB 10.5 MB/s eta 0:00:01
# ...

# %%
scrapper=pd.read_html("https://www.screener.in/company/compare/00000052/00000080/")

for idx, table in enumerate(scrapper):
    print("****************************************************************************")
    print(idx)
    print(table)
# Out:
# ****************************************************************************
# 0
#    S.No.              Name  CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# 0    1.0  Reliance Industr   2438.85  25.52       1650163.64        0.37
# 1    2.0           I O C L     91.55   5.26        129320.69        3.28
# 2    3.0           B P C L    348.40   3.71         75587.16        1.15
# 3    4.0           H P C L    251.80   4.28         35712.33        5.56
# 4    5.0           M R P L     91.10  16.96         15961.19        0.00
# 5    6.0           C P C L    510.10   4.41          7591.50        5.29
# 6    NaN     Median: 6 Co.    300.10   4.83         55649.75        2.21
#
#    NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  Qtr Sales Var  %  \
# 0        18258.00             -10.65          207559.00             -5.16
# 1        14735.30            1535.06          198550.77            -11.13
# 2        10644.30             279.24          112984.79             -6.69
# ...

# %%
df=scrapper[0]

df
# Out:
#    S.No.              Name  CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# 0    1.0  Reliance Industr   2438.85  25.52       1650163.64        0.37
# 1    2.0           I O C L     91.55   5.26        129320.69        3.28
# 2    3.0           B P C L    348.40   3.71         75587.16        1.15
# 3    4.0           H P C L    251.80   4.28         35712.33        5.56
# 4    5.0           M R P L     91.10  16.96         15961.19        0.00
# 5    6.0           C P C L    510.10   4.41          7591.50        5.29
# 6    NaN     Median: 6 Co.    300.10   4.83         55649.75        2.21
#
#    NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  Qtr Sales Var  %  \
# 0        18258.00             -10.65          207559.00             -5.16
# 1        14735.30            1535.06          198550.77            -11.13
# 2        10644.30             279.24          112984.79             -6.69
# 3         6765.50             179.06          112079.16             -2.12
# ...

# %%
df.columns
# Out:
# Index(['CMP  Rs.', 'P/E', 'Mar Cap  Rs.Cr.', 'Div Yld  %', 'NP Qtr  Rs.Cr.',
#        'Qtr Profit Var  %', 'Sales Qtr  Rs.Cr.', 'Qtr Sales Var  %',
#        'ROCE  %'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
df= df.drop(columns="S.No.")

# %%
df
# Out:
#                Name  CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# 0  Reliance Industr   2438.85  25.52       1650163.64        0.37
# 1           I O C L     91.55   5.26        129320.69        3.28
# 2           B P C L    348.40   3.71         75587.16        1.15
# 3           H P C L    251.80   4.28         35712.33        5.56
# 4           M R P L     91.10  16.96         15961.19        0.00
# 5           C P C L    510.10   4.41          7591.50        5.29
# 6     Median: 6 Co.    300.10   4.83         55649.75        2.21
#
#    NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  Qtr Sales Var  %  \
# 0        18258.00             -10.65          207559.00             -5.16
# 1        14735.30            1535.06          198550.77            -11.13
# 2        10644.30             279.24          112984.79             -6.69
# 3         6765.50             179.06          112079.16             -2.12
# ...

# %%
df.columns
# Out:
# Index(['CMP  Rs.', 'P/E', 'Mar Cap  Rs.Cr.', 'Div Yld  %', 'NP Qtr  Rs.Cr.',
#        'Qtr Profit Var  %', 'Sales Qtr  Rs.Cr.', 'Qtr Sales Var  %',
#        'ROCE  %'],
#       dtype='object')

# %%
df=df.set_index("Name")

# %%
df
# Out:
#                   CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# Name
# Reliance Industr   2438.85  25.52       1650163.64        0.37
# I O C L              91.55   5.26        129320.69        3.28
# B P C L             348.40   3.71         75587.16        1.15
# H P C L             251.80   4.28         35712.33        5.56
# M R P L              91.10  16.96         15961.19        0.00
# C P C L             510.10   4.41          7591.50        5.29
# Median: 6 Co.       300.10   4.83         55649.75        2.21
#
#                   NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  \
# Name
# Reliance Industr        18258.00             -10.65          207559.00
# I O C L                 14735.30            1535.06          198550.77
# B P C L                 10644.30             279.24          112984.79
# H P C L                  6765.50             179.06          112079.16
# M R P L                  1012.74             -62.60           21173.12
# ...

# %%
df.columns
# Out:
# Index(['CMP  Rs.', 'P/E', 'Mar Cap  Rs.Cr.', 'Div Yld  %', 'NP Qtr  Rs.Cr.',
#        'Qtr Profit Var  %', 'Sales Qtr  Rs.Cr.', 'Qtr Sales Var  %',
#        'ROCE  %'],
#       dtype='object')

# %%
df['Mar Cap  Rs.Cr.'].corr(df['CMP  Rs.'])
# Out:
# 0.9770156035795942

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#           CMP  Rs.        P/E  Mar Cap  Rs.Cr.  Div Yld  %  NP Qtr  Rs.Cr.  \
# count     7.000000   7.000000     7.000000e+00    7.000000        7.000000
# mean    575.985714   9.281429     2.814266e+05    2.551429     8667.008571
# std     834.406072   8.548145     6.049456e+05    2.252076     6593.419206
# min      91.100000   3.710000     7.591500e+03    0.000000      548.320000
# 25%     171.675000   4.345000     2.583676e+04    0.760000     3889.120000
# 50%     300.100000   4.830000     5.564975e+04    2.210000     8704.900000
# 75%     429.250000  11.110000     1.024539e+05    4.285000    12689.800000
# max    2438.850000  25.520000     1.650164e+06    5.560000    18258.000000
#
#        Qtr Profit Var  %  Sales Qtr  Rs.Cr.  Qtr Sales Var  %    ROCE  %
# count           7.000000           7.000000          7.000000   7.000000
# mean          275.365714      111374.802857        -14.968571  13.101429
# std           570.478617       75640.792903         14.240521  16.525288
# ...

# %%
df.transpose()
# Out:
# Name               Reliance Industr    I O C L    B P C L    H P C L  \
# CMP  Rs.                    2438.85      91.55     348.40     251.80
# P/E                           25.52       5.26       3.71       4.28
# Mar Cap  Rs.Cr.          1650163.64  129320.69   75587.16   35712.33
# Div Yld  %                     0.37       3.28       1.15       5.56
# NP Qtr  Rs.Cr.             18258.00   14735.30   10644.30    6765.50
# Qtr Profit Var  %            -10.65    1535.06     279.24     179.06
# Sales Qtr  Rs.Cr.         207559.00  198550.77  112984.79  112079.16
# Qtr Sales Var  %              -5.16     -11.13      -6.69      -2.12
# ROCE  %                       10.04       8.16       6.86      -8.08
#
# Name                M R P L   C P C L  Median: 6 Co.
# CMP  Rs.              91.10    510.10         300.10
# P/E                   16.96      4.41           4.83
# Mar Cap  Rs.Cr.    15961.19   7591.50       55649.75
# Div Yld  %             0.00      5.29           2.21
# ...

# %%
df.sort_values(by='P/E',ascending=False)
# Out:
#                   CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# Name
# Reliance Industr   2438.85  25.52       1650163.64        0.37
# M R P L              91.10  16.96         15961.19        0.00
# I O C L              91.55   5.26        129320.69        3.28
# Median: 6 Co.       300.10   4.83         55649.75        2.21
# C P C L             510.10   4.41          7591.50        5.29
# H P C L             251.80   4.28         35712.33        5.56
# B P C L             348.40   3.71         75587.16        1.15
#
#                   NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  \
# Name
# Reliance Industr        18258.00             -10.65          207559.00
# M R P L                  1012.74             -62.60           21173.12
# I O C L                 14735.30            1535.06          198550.77
# Median: 6 Co.            8704.90              84.20          112531.98
# C P C L                   548.32             -76.75           14744.80
# ...

# %%
df.index
# Out:
# Index(['Reliance Industr', 'I O C L', 'B P C L', 'H P C L', 'M R P L',
#        'C P C L', 'Median: 6 Co.'],
#       dtype='object', name='Name')

# %% [markdown]
# slicing rows

# %%
df[0:6]
# Out:
#                   CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# Name
# Reliance Industr   2438.85  25.52       1650163.64        0.37
# I O C L              91.55   5.26        129320.69        3.28
# B P C L             348.40   3.71         75587.16        1.15
# H P C L             251.80   4.28         35712.33        5.56
# M R P L              91.10  16.96         15961.19        0.00
# C P C L             510.10   4.41          7591.50        5.29
#
#                   NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  \
# Name
# Reliance Industr        18258.00             -10.65          207559.00
# I O C L                 14735.30            1535.06          198550.77
# B P C L                 10644.30             279.24          112984.79
# H P C L                  6765.50             179.06          112079.16
# M R P L                  1012.74             -62.60           21173.12
# C P C L                   548.32             -76.75           14744.80
#
# ...

# %%
df.reset_index()
# Out:
#                Name  CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# 0  Reliance Industr   2438.85  25.52       1650163.64        0.37
# 1           I O C L     91.55   5.26        129320.69        3.28
# 2           B P C L    348.40   3.71         75587.16        1.15
# 3           H P C L    251.80   4.28         35712.33        5.56
# 4           M R P L     91.10  16.96         15961.19        0.00
# 5           C P C L    510.10   4.41          7591.50        5.29
# 6     Median: 6 Co.    300.10   4.83         55649.75        2.21
#
#    NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  Qtr Sales Var  %  \
# 0        18258.00             -10.65          207559.00             -5.16
# 1        14735.30            1535.06          198550.77            -11.13
# 2        10644.30             279.24          112984.79             -6.69
# 3         6765.50             179.06          112079.16             -2.12
# ...

# %%
df.index
# Out:
# Index(['Reliance Industr', 'I O C L', 'B P C L', 'H P C L', 'M R P L',
#        'C P C L', 'Median: 6 Co.'],
#       dtype='object', name='Name')

# %%
df
# Out:
#                   CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# Name
# Reliance Industr   2438.85  25.52       1650163.64        0.37
# I O C L              91.55   5.26        129320.69        3.28
# B P C L             348.40   3.71         75587.16        1.15
# H P C L             251.80   4.28         35712.33        5.56
# M R P L              91.10  16.96         15961.19        0.00
# C P C L             510.10   4.41          7591.50        5.29
# Median: 6 Co.       300.10   4.83         55649.75        2.21
#
#                   NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  \
# Name
# Reliance Industr        18258.00             -10.65          207559.00
# I O C L                 14735.30            1535.06          198550.77
# B P C L                 10644.30             279.24          112984.79
# H P C L                  6765.50             179.06          112079.16
# M R P L                  1012.74             -62.60           21173.12
# ...

# %%
df['Name']=['Reliance Industr', 'I O C L', 'B P C L', 'H P C L', 'M R P L',
       'C P C L', 'Median: 6 Co.']

# %%
df
# Out:
#                   CMP  Rs.    P/E  Mar Cap  Rs.Cr.  Div Yld  %  \
# Name
# Reliance Industr   2438.85  25.52       1650163.64        0.37
# I O C L              91.55   5.26        129320.69        3.28
# B P C L             348.40   3.71         75587.16        1.15
# H P C L             251.80   4.28         35712.33        5.56
# M R P L              91.10  16.96         15961.19        0.00
# C P C L             510.10   4.41          7591.50        5.29
# Median: 6 Co.       300.10   4.83         55649.75        2.21
#
#                   NP Qtr  Rs.Cr.  Qtr Profit Var  %  Sales Qtr  Rs.Cr.  \
# Name
# Reliance Industr        18258.00             -10.65          207559.00
# I O C L                 14735.30            1535.06          198550.77
# B P C L                 10644.30             279.24          112984.79
# H P C L                  6765.50             179.06          112079.16
# M R P L                  1012.74             -62.60           21173.12
# ...

# %%
df.columns
# Out:
# Index(['CMP  Rs.', 'P/E', 'Mar Cap  Rs.Cr.', 'Div Yld  %', 'NP Qtr  Rs.Cr.',
#        'Qtr Profit Var  %', 'Sales Qtr  Rs.Cr.', 'Qtr Sales Var  %', 'ROCE  %',
#        'Name'],
#       dtype='object')

# %%
sns.barplot(x="Name", y='Mar Cap  Rs.Cr.' ,data=df)
# Out:
# <Axes: xlabel='Name', ylabel='Mar Cap  Rs.Cr.'>
